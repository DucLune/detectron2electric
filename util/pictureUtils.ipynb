# %%
import os
import random
import shutil
import labelme2coco
import glob

# %%
# src_dirname:图片存储目录
# componentType零件类型
# componentCount零件数量
# startIndex起始零件编号
# startPosition起始面编号
# positions面的数量
# prefix文件名前缀
def namepictures(src_dirname, componentType, componentCount, startIndex=1, startPosition=1, positions=4, prefix="Image"):
    list_data = os.listdir(src_dirname)
    list_data.sort()
    currentIndex = startIndex
    currentPosition = startPosition
    count = 0
    for filename in list_data:
        if filename[:5] == prefix:
            title = filename.split(".")
            #print(componenttype+str(currentIndex) +'-'+str(currentPosition)+'.'+title[1])
            print("Renaming "+os.path.join(src_dirname, filename)+" -> "+os.path.join(src_dirname, componentType+str(currentIndex) + '-'+str(currentPosition)+'.'+title[1]))
            os.rename(os.path.join(src_dirname, filename), os.path.join(
                src_dirname, componentType+str(currentIndex) + '-'+str(currentPosition)+'.'+title[1]))
            currentPosition += 1
            if currentPosition == startPosition+positions:
                currentPosition = startPosition
                currentIndex += 1
                count += 1
                if count == componentCount:
                    break
    return

# %%
#namepictures("../t","D",8)
# Out:
# Renaming ../t/Image_20211212150532521.bmp -> ../t/D1-1.bmp
# Renaming ../t/Image_20211212150605206.bmp -> ../t/D1-2.bmp
# Renaming ../t/Image_20211212150626582.bmp -> ../t/D1-3.bmp
# Renaming ../t/Image_20211212150634456.bmp -> ../t/D1-4.bmp
# Renaming ../t/Image_20211212150856108.bmp -> ../t/D2-1.bmp
# Renaming ../t/Image_20211212150908948.bmp -> ../t/D2-2.bmp
# Renaming ../t/Image_20211212150917078.bmp -> ../t/D2-3.bmp
# Renaming ../t/Image_20211212150922711.bmp -> ../t/D2-4.bmp
# Renaming ../t/Image_20211212151017449.bmp -> ../t/D3-1.bmp
# Renaming ../t/Image_20211212151021766.bmp -> ../t/D3-2.bmp
# Renaming ../t/Image_20211212151045630.bmp -> ../t/D3-3.bmp
# Renaming ../t/Image_20211212151053731.bmp -> ../t/D3-4.bmp
# Renaming ../t/Image_20211212151232182.bmp -> ../t/D4-1.bmp
# Renaming ../t/Image_20211212151237334.bmp -> ../t/D4-2.bmp
# Renaming ../t/Image_20211212151247910.bmp -> ../t/D4-3.bmp
# Renaming ../t/Image_20211212151252747.bmp -> ../t/D4-4.bmp
# Renaming ../t/Image_20211212151402647.bmp -> ../t/D5-1.bmp
# Renaming ../t/Image_20211212151417528.bmp -> ../t/D5-2.bmp
# Renaming ../t/Image_20211212151423302.bmp -> ../t/D5-3.bmp
# Renaming ../t/Image_20211212151427951.bmp -> ../t/D5-4.bmp
# Renaming ../t/Image_20211212151537230.bmp -> ../t/D6-1.bmp
# Renaming ../t/Image_20211212151542367.bmp -> ../t/D6-2.bmp
# Renaming ../t/Image_20211212151547894.bmp -> ../t/D6-3.bmp
# Renaming ../t/Image_20211212151554599.bmp -> ../t/D6-4.bmp
# Renaming ../t/Image_20211212151624787.bmp -> ../t/D7-1.bmp
# Renaming ../t/Image_20211212151639516.bmp -> ../t/D7-2.bmp
# Renaming ../t/Image_20211212151648510.bmp -> ../t/D7-3.bmp
# Renaming ../t/Image_20211212151711774.bmp -> ../t/D7-4.bmp
# Renaming ../t/Image_20211212151806171.bmp -> ../t/D8-1.bmp
# Renaming ../t/Image_20211212151812126.bmp -> ../t/D8-2.bmp
# Renaming ../t/Image_20211212151823422.bmp -> ../t/D8-3.bmp
# Renaming ../t/Image_20211212151838197.bmp -> ../t/D8-4.bmp

# %%
import cv2


def bmp2jpg(src_dirname):
    list_data = os.listdir(src_dirname)
    for filename in list_data:
        if filename.split('.')[1] != 'bmp':
            continue
        im = cv2.imread(os.path.join(src_dirname, filename))
        print("Converting "+os.path.join(src_dirname, filename)+" to " +
              os.path.join(src_dirname, filename.split('.')[0]+'.jpg'))
        cv2.imwrite(os.path.join(
            src_dirname, filename.split('.')[0]+'.jpg'), im)


#bmp2jpg("../t")
# Out:
# Converting ../t/B5-4.bmp to ../t/B5-4.jpg
# Converting ../t/D2-4.bmp to ../t/D2-4.jpg
# Converting ../t/E6-1.bmp to ../t/E6-1.jpg
# Converting ../t/D4-2.bmp to ../t/D4-2.jpg
# Converting ../t/E5-3.bmp to ../t/E5-3.jpg
# Converting ../t/D3-4.bmp to ../t/D3-4.jpg
# Converting ../t/E3-1.bmp to ../t/E3-1.jpg
# Converting ../t/B5-1.bmp to ../t/B5-1.jpg
# Converting ../t/D5-1.bmp to ../t/D5-1.jpg
# Converting ../t/D2-1.bmp to ../t/D2-1.jpg
# Converting ../t/B7-2.bmp to ../t/B7-2.jpg
# Converting ../t/E6-3.bmp to ../t/E6-3.jpg
# Converting ../t/B5-3.bmp to ../t/B5-3.jpg
# Converting ../t/D8-2.bmp to ../t/D8-2.jpg
# Converting ../t/B6-1.bmp to ../t/B6-1.jpg
# Converting ../t/D6-2.bmp to ../t/D6-2.jpg
# Converting ../t/D6-4.bmp to ../t/D6-4.jpg
# Converting ../t/B6-4.bmp to ../t/B6-4.jpg
# Converting ../t/B9-4.bmp to ../t/B9-4.jpg
# Converting ../t/D3-3.bmp to ../t/D3-3.jpg
# Converting ../t/E1-1.bmp to ../t/E1-1.jpg
# Converting ../t/E7-3.bmp to ../t/E7-3.jpg
# Converting ../t/B5-2.bmp to ../t/B5-2.jpg
# Converting ../t/B6-3.bmp to ../t/B6-3.jpg
# Converting ../t/D4-4.bmp to ../t/D4-4.jpg
# Converting ../t/E7-2.bmp to ../t/E7-2.jpg
# Converting ../t/B8-4.bmp to ../t/B8-4.jpg
# Converting ../t/D2-3.bmp to ../t/D2-3.jpg
# Converting ../t/D8-1.bmp to ../t/D8-1.jpg
# Converting ../t/E2-2.bmp to ../t/E2-2.jpg
# Converting ../t/D6-3.bmp to ../t/D6-3.jpg
# Converting ../t/D7-3.bmp to ../t/D7-3.jpg
# Converting ../t/E2-4.bmp to ../t/E2-4.jpg
# Converting ../t/E6-4.bmp to ../t/E6-4.jpg
# Converting ../t/E5-2.bmp to ../t/E5-2.jpg
# Converting ../t/B7-4.bmp to ../t/B7-4.jpg
# Converting ../t/E5-1.bmp to ../t/E5-1.jpg
# Converting ../t/D3-2.bmp to ../t/D3-2.jpg
# Converting ../t/E5-4.bmp to ../t/E5-4.jpg
# Converting ../t/E4-2.bmp to ../t/E4-2.jpg
# Converting ../t/D5-2.bmp to ../t/D5-2.jpg
# Converting ../t/B8-1.bmp to ../t/B8-1.jpg
# Converting ../t/E2-3.bmp to ../t/E2-3.jpg
# Converting ../t/E4-1.bmp to ../t/E4-1.jpg
# Converting ../t/D8-3.bmp to ../t/D8-3.jpg
# Converting ../t/E1-4.bmp to ../t/E1-4.jpg
# Converting ../t/D8-4.bmp to ../t/D8-4.jpg
# Converting ../t/D4-1.bmp to ../t/D4-1.jpg
# Converting ../t/D2-2.bmp to ../t/D2-2.jpg
# Converting ../t/D7-4.bmp to ../t/D7-4.jpg
# Converting ../t/D7-2.bmp to ../t/D7-2.jpg
# Converting ../t/B8-3.bmp to ../t/B8-3.jpg
# Converting ../t/D1-1.bmp to ../t/D1-1.jpg
# Converting ../t/E1-3.bmp to ../t/E1-3.jpg
# Converting ../t/E6-2.bmp to ../t/E6-2.jpg
# Converting ../t/D3-1.bmp to ../t/D3-1.jpg
# Converting ../t/E3-3.bmp to ../t/E3-3.jpg
# Converting ../t/B9-1.bmp to ../t/B9-1.jpg
# Converting ../t/B7-3.bmp to ../t/B7-3.jpg
# Converting ../t/D4-3.bmp to ../t/D4-3.jpg
# Converting ../t/B9-2.bmp to ../t/B9-2.jpg
# Converting ../t/B7-1.bmp to ../t/B7-1.jpg
# Converting ../t/D5-3.bmp to ../t/D5-3.jpg
# Converting ../t/E7-1.bmp to ../t/E7-1.jpg
# Converting ../t/D7-1.bmp to ../t/D7-1.jpg
# Converting ../t/B9-3.bmp to ../t/B9-3.jpg
# Converting ../t/E2-1.bmp to ../t/E2-1.jpg
# Converting ../t/E4-3.bmp to ../t/E4-3.jpg
# Converting ../t/E4-4.bmp to ../t/E4-4.jpg
# Converting ../t/D5-4.bmp to ../t/D5-4.jpg
# Converting ../t/D6-1.bmp to ../t/D6-1.jpg
# Converting ../t/D1-2.bmp to ../t/D1-2.jpg
# Converting ../t/B8-2.bmp to ../t/B8-2.jpg
# Converting ../t/D1-3.bmp to ../t/D1-3.jpg
# Converting ../t/E1-2.bmp to ../t/E1-2.jpg
# Converting ../t/D1-4.bmp to ../t/D1-4.jpg
# Converting ../t/B6-2.bmp to ../t/B6-2.jpg
# Converting ../t/E3-2.bmp to ../t/E3-2.jpg
# Converting ../t/E7-4.bmp to ../t/E7-4.jpg
# Converting ../t/E3-4.bmp to ../t/E3-4.jpg

# %%
# 图片和标注放在两个不同的文件夹
# 图片放在pics_dir中，标注放在anno_dir中

def buildCocoDataset(anno_src_dir,dataset_dir,labels=[], train_portion=0.7, val_portion=0.15, test_portion=0.15):
    os.makedirs(dataset_dir, exist_ok=True)
    anno_dest_dir = os.path.join(dataset_dir, "annotations")
    os.makedirs(anno_dest_dir, exist_ok=True)
    train_dir = os.path.join(dataset_dir, "train")
    os.makedirs(train_dir, exist_ok=True)
    val_dir = os.path.join(dataset_dir, "val")
    os.makedirs(val_dir, exist_ok=True)
    test_dir = os.path.join(dataset_dir, "test")
    os.makedirs(test_dir, exist_ok=True)
    list_data = os.listdir(anno_src_dir)
    random.shuffle(list_data)
    list_train = list_data[:int(train_portion*len(list_data))]
    list_val = list_data[int(train_portion*len(list_data)):int((train_portion+val_portion)*len(list_data))]
    list_test = list_data[int((train_portion+val_portion)*len(list_data)):]
    count = 0
    for filename in list_train:
        shutil.copy(os.path.join(anno_src_dir, filename),train_dir)
    for filename in list_val:
        shutil.copy(os.path.join(anno_src_dir, filename),val_dir)
    for filename in list_test:
        shutil.copy(os.path.join(anno_src_dir, filename),test_dir)
    labelme2coco.labelme2coco(glob.glob(os.path.join(train_dir,"*.json")),os.path.join(anno_dest_dir,"train.json"),labels)
    labelme2coco.labelme2coco(glob.glob(os.path.join(val_dir,"*.json")),os.path.join(anno_dest_dir,"val.json"),labels)
    labelme2coco.labelme2coco(glob.glob(os.path.join(test_dir,"*.json")),os.path.join(anno_dest_dir,"test.json"),labels) 

#print(os.getcwd())
#buildCocoDataset("../Annotations/glue_pin_inclined_side_pin_glue_injection_hole_regular_part","../dataset/coco-20211215",["glue","injection_hole"])
# Out:
# d:\Git\detectron2electric\util
